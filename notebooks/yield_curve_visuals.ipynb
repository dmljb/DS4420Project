# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../macro_monthly_clean.csv", index_col=0, parse_dates=True)

yield_cols = ["treasury_1y", "treasury_2y", "treasury_5y", "treasury_10y"]

df = df[yield_cols].dropna()
df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       4 df = pd.read_csv("../macro_monthly_clean.csv", index_col=0, parse_dates=True)
#       6 yield_cols = ["treasury_1y", "treasury_2y", "treasury_5y", "treasury_10y"]
#
# File c:\Users\denis\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\__init__.py:1001
#     995     _log.debug('loaded rc file %s', fname)
#     997     return config
#    1000 rcParamsDefault = _rc_params_in_file(
# -> 1001     cbook._get_data_path("matplotlibrc"),
#    1002     # Strip leading comment.
#    1003     transform=lambda line: line[1:] if line.startswith("#") else line,
#    1004     fail_on_error=True)
#    1005 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#    1006 rcParamsDefault._ensure_has_backend()
#
# File c:\Users\denis\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\matplotlib\cbook.py:603, in _get_data_path(*args)
#     597 def _get_data_path(*args):
#     598     """
#     599     Return the `pathlib.Path` to a resource file provided by Matplotlib.
#     600
#     601     ``*args`` specify a path relative to the base data path.
#     602     """
# --> 603     return Path(matplotlib.get_data_path(), *args)
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'
